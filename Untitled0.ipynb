# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/YashPatel1508/Basic-AI-ML.git
# %cd Basic-AI-ML
# Out:
# Cloning into 'Basic-AI-ML'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 274.63 KiB | 10.56 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/Basic-AI-ML

# %%
# !cp -r "/content/drive/MyDrive/YOUR_FOLDER/." .
